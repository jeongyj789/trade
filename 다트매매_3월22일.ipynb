# %%
from selenium import webdriver
import xlrd
import pandas as pd
import os
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium.webdriver.common.alert import Alert
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time
from datetime import datetime
from selenium.common.exceptions import TimeoutException
import telepot


my_token = '717046544:AAG_KgX76YL2no2uHXTeJNUjuXldAEDGeMk'  # 토큰을 설정해 줍니다.

bot = telepot.Bot(token=my_token)  # 봇을0 생성합니다.

# %%
# 자동매매 api

import sys
from PyQt5.QtWidgets import *
import win32com.client
import ctypes

# %%
driver = webdriver.Chrome("D:/file/chromedriver.exe")

file_list = pd.read_excel('D:/file/상장기업목록.xlsx')

driver.get("http://dart.fss.or.kr/dsac001/mainAll.do")

# %%
# <업종보고 판단하기>
# 체결 = 1분내 재판매

# 무상, 유상 = 5퍼 이상 알람,

key_array = ['공개매수신고서','공급계약체결','체결','취득','자기주식',
             '단일','무상','증자','유상','특허','상장폐지']

# %%
date= [0] # 날짜
site_time=[0]
site_name = [0] # 회사이름
site_report_name = [0] # 보고서명
site_report_url = [0] # 보고서 주소
company_type = [0] # 회사업종명

while True:
    # 오늘날짜 조회
    # 최근공시 - 전체
    
    WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, '''//*[@id="layoutLeft"]/div[1]/ul/li[5]/a/img'''))).click()
    
    # 한번에 10개 조회
    for i in range(1, 10, 1):

        # 회사이름
        name = WebDriverWait(driver, 20).until(EC.presence_of_element_located(
            (By.XPATH, """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[2]/span/a""".format(i)))).text
        
        # 사이트 시간
        this_time = driver.find_element_by_xpath(
            """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[1]""".format(i)).text
        # 보고서명
        report = driver.find_element_by_xpath(
            """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[3]""".format(i)).text
        
        print(name, this_time, report)
        
        if ((name in str(site_name)) & (report in str(site_report_name)) & (this_time in str(site_time))):

            # 중복조회 제거
            continue
            
        else:

            # 중복이 아니면
            for element in key_array:

                # 제외키워드 목록
                if ((element in report) &
                        ('기재정정' not in report) &
                        ('특수관계인' not in report) &
                        ('결과' not in report) &
                        ('타법인' not in report) &
                        ('사채' not in report) &
                        ('해지' not in report) &
                        ('최대주주' not in report) &
                        ('비유동자산' not in report) &
                        ('처분' not in report) &
                        ('첨부' not in report) &
                        ('위탁' not in report) &
                        ('연장' not in report) &
                        ('신탁계약에의한취득상황보고서' not in report)):
                    
                    print("dd")

# 
                    
                    date.append(driver.find_element_by_xpath(
                        """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[5]""".format(i)).text)
#                         print(date[-1])
                    site_time.append(driver.find_element_by_xpath(
                        """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[1]""".format(i)).text)
#                         print(site_time[-1])
                    site_name.append(driver.find_element_by_xpath(
                        """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[2]/span/a""".format(i)).text)
#                         print(site_name[-1])
                    site_report_name.append(driver.find_element_by_xpath(
                        """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[3]""".format(i)).text)
#                         print(site_report_name[-1])
                    site_report_url.append(driver.find_element_by_xpath(
                        """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[3]/a""".format(i)).get_attribute(
                        "href"))
#                         print(site_report_url[-1])

                    print(element,"/", date[-1],"/", site_time[-1],"/", site_name[-1],"/", site_report_name[-1],"/", site_report_url[-1])


                    if name in list(file_list.회사명):
                        
                        company_type.append(file_list.loc[file_list.회사명 == name, '업종'].values[0])
                        date.append(driver.find_element_by_xpath(
                            """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[5]""".format(i)).text)
                        site_time.append(driver.find_element_by_xpath(
                            """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[1]""".format(i)).text)
                        site_name.append(driver.find_element_by_xpath(
                            """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[2]/span/a""".format(i)).text)
                        site_report_name.append(driver.find_element_by_xpath(
                            """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[3]""".format(i)).text)
                        site_report_url.append(driver.find_element_by_xpath(
                            """//*[@id="listContents"]/div[1]/table/tbody/tr[{}]/td[3]/a""".format(i)).get_attribute(
                            "href"))

                        print(element,"/", company_type[-1],"/", date[-1],"/", site_time[-1],"/", site_name[-1],"/", site_report_name[-1],"/", site_report_url[-1])

#                         bot.sendMessage(chat_id='@FuckingSB', text='----------------------')

#                         bot.sendMessage(chat_id='@FuckingSB', text=site_name[-1])  # @bill_chat 으로 메세지를 보냅니다.

#                         bot.sendMessage(chat_id='@FuckingSB', text=company_type[-1])  # @bill_chat 으로 메세지를 보냅니다.

#                         bot.sendMessage(chat_id='@FuckingSB', text=site_report_name[-1])
#                         bot.sendMessage(chat_id='@FuckingSB', text=site_report_url[-1])
#                         bot.sendMessage(chat_id='@FuckingSB', text=site_time[-1])
#                         bot.sendMessage(chat_id='@FuckingSB', text='----------------------')
# Out:
# 솔고바이오 23:01 주권매매거래정지기간변경 (상장적격성 실질심사 대상(사유발생))
# 하이소닉 22:39 기타시장안내 (상장폐지 관련)
# dd
# 상장폐지 / 2020.03.20 / 22:39 / 하이소닉 / 기타시장안내 (상장폐지 관련) / http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20200320902491
# 하이소닉 22:38 기타시장안내 (상장적격성 실질심사관련)
# 더블유에프엠 22:18 기타시장안내 (상장폐지 관련 안내)
# dd
# 상장폐지 / 2020.03.20 / 22:18 / 더블유에프엠 / 기타시장안내 (상장폐지 관련 안내) / http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20200320902489
# 상장폐지 / 서적, 잡지 및 기타 인쇄물 출판업 / 2020.03.20 / 22:18 / 더블유에프엠 / 기타시장안내 (상장폐지 관련 안내) / http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20200320902489
# 더블유에프엠 22:13 주권매매거래정지기간변경 (상장폐지 사유 발생)
# dd
# 상장폐지 / 2020.03.20 / 22:13 / 더블유에프엠 / 주권매매거래정지기간변경 (상장폐지 사유 발생) / http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20200320902488
# 상장폐지 / 서적, 잡지 및 기타 인쇄물 출판업 / 2020.03.20 / 22:13 / 더블유에프엠 / 주권매매거래정지기간변경 (상장폐지 사유 발생) / http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20200320902488
# 코너스톤네트웍스 22:11 주권매매거래정지기간변경 (상장폐지 사유 발생)
# dd
# ...

# %%
                        objCpCybos = win32com.client.Dispatch("CpUtil.CpCybos")
                        bConnect = objCpCybos.IsConnect
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-f11b1d7365ad> in <module>
# ----> 1 objCpCybos = win32com.client.Dispatch("CpUtil.CpCybos")
#       2 bConnect = objCpCybos.IsConnect
#
# NameError: name 'win32com' is not defined

# %%
                        # 연결 여부 체크

                        # if '무상증자' in report :


                        objCpCybos = win32com.client.Dispatch("CpUtil.CpCybos")
                        bConnect = objCpCybos.IsConnect
                        if (bConnect == 0):
                            print("PLUS가 정상적으로 연결되지 않음. ")
                            exit()

                        # 코드 반환
                        instCpStockCode = win32com.client.Dispatch("CpUtil.CpStockCode")

                        name_code = instCpStockCode.NameToCode(name)

                        # 현재가 객체 구하기

                        objStockMst = win32com.client.Dispatch("DsCbo1.StockMst")
                        objStockMst.SetInputValue(0, name_code)  # 종목 코드 - 삼성전자
                        objStockMst.BlockRequest()

                        # 현재가 통신 및 통신 에러 처리
                        rqStatus = objStockMst.GetDibStatus()
                        rqRet = objStockMst.GetDibMsg1()
                        print("통신상태", rqStatus, rqRet)
                        if rqStatus != 0:
                            exit()

                        code = objStockMst.GetHeaderValue(0)  # 종목코드
                        name = objStockMst.GetHeaderValue(1)  # 종목명
                        #time = objStockMst.GetHeaderValue(4)  # 시간
                        cprice = objStockMst.GetHeaderValue(11)  # 종가
                        diff = objStockMst.GetHeaderValue(12)  # 대비
                        open = objStockMst.GetHeaderValue(13)  # 시가
                        high = objStockMst.GetHeaderValue(14)  # 고가
                        low = objStockMst.GetHeaderValue(15)  # 저가
                        offer = objStockMst.GetHeaderValue(16)  # 매도호가
                        bid = objStockMst.GetHeaderValue(17)  # 매수호가

                        # 주문 초기화
                        objTrade = win32com.client.Dispatch("CpTrade.CpTdUtil")
                        initCheck = objTrade.TradeInit(0)
                        if (initCheck != 0):
                            print("주문 초기화 실패")
                            exit()

                        # 주식 매수 주문
                        acc = objTrade.AccountNumber[0]  # 계좌번호
                        accFlag = objTrade.GoodsList(acc, 1)  # 주식상품 구분
                        objStockOrder = win32com.client.Dispatch("CpTrade.CpTd0311")
                        objStockOrder.SetInputValue(0, "2")  # 2: 매수
                        objStockOrder.SetInputValue(1, acc)  # 계좌번호
                        objStockOrder.SetInputValue(2, accFlag[0])  # 상품구분 - 주식 상품 중 첫번째
                        objStockOrder.SetInputValue(3, name_code)  # 종목코드 - A003540 - 대신증권 종목

                        if int(bid) < 1000:
                            objStockOrder.SetInputValue(4, 1)
                            bid = bid + 1
                        elif int(bid) < 5000:
                            objStockOrder.SetInputValue(4, 1)  # 매수수량 1주

                            bid = bid + 5
                        elif int(bid) < 10000:
                            objStockOrder.SetInputValue(4, 1)  # 매수수량 1주
                            bid = bid + 10

                        elif int(bid) < 50000:
                            objStockOrder.SetInputValue(4, 1)
                            bid = bid + 50

                        elif int(bid) < 100000:
                            objStockOrder.SetInputValue(4, 1)
                            bid = bid + 100

                        # objStockOrder.SetInputValue(4, 1)  # 매수수량 1주

                        objStockOrder.SetInputValue(5, bid)  # 주문단가  - bid
                        
                        objStockOrder.BlockRequest()
 
                        rqStatus = objStockOrder.GetDibStatus()
                        rqRet = objStockOrder.GetDibMsg1()
                        print("통신상태", rqStatus, rqRet)
                        if rqStatus != 0:
                            exit()
                        
                        # objStockOrder.SetInputValue(7, "0")  # 주문 조건 구분 코드, 0: 기본 1: IOC 2:FOK
                        # objStockOrder.SetInputValue(8, "01")  # 주문호가 구분코드 - 01: 보통

                        
                        
# 매도 까지 걸리는 시간은?
# Out:
# 일괄신고 / 금융 지원 서비스업 / 2019.10.24 / 13:50 / 교보증권 / 일괄신고추가서류(파생결합증권-주가연계증권) / http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20191024000108
# 통신상태 0 0027 조회가 완료되었습니다.(stock.new.mst)
# 통신상태 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\envs\venv32\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-cf629a978707> in <module>
#      16         # 회사이름
# ...

# %%
                        import telegram
    
                        my_token = '717046544:AAG_KgX76YL2no2uHXTeJNUjuXldAEDGeMk'  # 토큰을 설정해 줍니다.

                        bot = telegram.Bot(token=my_token)  # 봇을0 생성합니다.
            

                    
                        bot.sendMessage(chat_id='@FuckingSB', text='----------------------')

                        bot.sendMessage(chat_id='@FuckingSB', text=site_name[-1])  # @bill_chat 으로 메세지를 보냅니다.

                        bot.sendMessage(chat_id='@FuckingSB', text=company_type[-1])  # @bill_chat 으로 메세지를 보냅니다.

                        bot.sendMessage(chat_id='@FuckingSB', text=site_report_name[-1])
                        bot.sendMessage(chat_id='@FuckingSB', text=site_report_url[-1])
                        bot.sendMessage(chat_id='@FuckingSB', text=site_time[-1])
                        bot.sendMessage(chat_id='@FuckingSB', text='----------------------')

#                         if element == '무상':

#                             bot.sendMessage(chat_id='@Stockwithf', text='----------------------')
#                             bot.sendMessage(chat_id='@Stockwithf', text=site_name[-1])  # @bill_chat 으로 메세지를 보냅니다.
#                             bot.sendMessage(chat_id='@FuckingSB', text=company_type[-1])  # @bill_chat 으로 메세지를 보냅니다.
#                             bot.sendMessage(chat_id='@Stockwithf', text=site_report_name[-1])
#                             bot.sendMessage(chat_id='@Stockwithf', text=site_report_url[-1])
#                             bot.sendMessage(chat_id='@Stockwithf', text=site_time[-1])
#                             bot.sendMessage(chat_id='@Stockwithf', text='----------------------')

# %%
                        # 매도 주문 요청
                        
                        objStockOrder.BlockRequest()

                        rqStatus = objStockOrder.GetDibStatus()
                        rqRet = objStockOrder.GetDibMsg1()
                        print("통신상태", rqStatus, rqRet)
                        if rqStatus != 0:
                            exit()

                        time.sleep(15)


                        acc = objTrade.AccountNumber[0]  # 계좌번호
                        accFlag = objTrade.GoodsList(acc, 1)  # 주식상품 구분
                        print(acc, accFlag[0])
                        objStockOrder = win32com.client.Dispatch("CpTrade.CpTd0311")
                        objStockOrder.SetInputValue(0, "1")  # 1: 매도
                        objStockOrder.SetInputValue(1, acc)  # 계좌번호
                        objStockOrder.SetInputValue(2, accFlag[0])  # 상품구분 - 주식 상품 중 첫번째
                        objStockOrder.SetInputValue(3, name_code)  # 종목코드 - A003540 - 대신증권 종목
                        objStockOrder.SetInputValue(4, 1)  # 매도수량 10주



                        # 현재가 객체 구하기

                        objStockMst = win32com.client.Dispatch("DsCbo1.StockMst")
                        objStockMst.SetInputValue(0, name_code)  # 종목 코드 - 삼성전자
                        objStockMst.BlockRequest()

                        # 현재가 통신 및 통신 에러 처리
                        rqStatus = objStockMst.GetDibStatus()
                        rqRet = objStockMst.GetDibMsg1()
                        print("통신상태", rqStatus, rqRet)
                        if rqStatus != 0:
                            exit()

                        code = objStockMst.GetHeaderValue(0)  # 종목코드
                        name = objStockMst.GetHeaderValue(1)  # 종목명
                        time = objStockMst.GetHeaderValue(4)  # 시간
                        cprice = objStockMst.GetHeaderValue(11)  # 종가
                        diff = objStockMst.GetHeaderValue(12)  # 대비
                        open = objStockMst.GetHeaderValue(13)  # 시가
                        high = objStockMst.GetHeaderValue(14)  # 고가
                        low = objStockMst.GetHeaderValue(15)  # 저가
                        offer = objStockMst.GetHeaderValue(16)  # 매도호가
                        bid = objStockMst.GetHeaderValue(17)  # 매수호가






                        objStockOrder.SetInputValue(5, offer)  # 주문단가  - 14,100원
                        objStockOrder.SetInputValue(7, "0")  # 주문 조건 구분 코드, 0: 기본 1: IOC 2:FOK
                        objStockOrder.SetInputValue(8, "01")  # 주문호가 구분코드 - 01: 보통



                        rqStatus = objStockOrder.GetDibStatus()
                        rqRet = objStockOrder.GetDibMsg1()
                        print("통신상태", rqStatus, rqRet)
                        if rqStatus != 0:
                            exit()

                        break
